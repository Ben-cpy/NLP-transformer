# %% [markdown]
# **包含内容**
# - 关键类：EncoderDecoder、Multi-Head Attention、Feed Forward、Embedding、位置编码
# - 构建完整模型的工厂函数 make_model
# - 示例：创建标准配置模型

# %%
# 导入核心组件
from transformer_utils import (
    EncoderDecoder,
    Generator,
    Encoder, EncoderLayer,
    Decoder, DecoderLayer,
    MultiHeadedAttention,
    PositionwiseFeedForward,
    Embeddings, PositionalEncoding,
    subsequent_mask, make_model, device,
)
print('核心组件已加载，设备:', device)

# %% [markdown]
# ## 示例：创建标准Base模型
# 可修改超参数 N、d_model、d_ff、h、dropout 观察结构变化。

# %%
# 创建一个标准6层、8头的Transformer
model = make_model(src_vocab=10000, tgt_vocab=10000, N=6, d_model=512, d_ff=2048, h=8, dropout=0.1)
print(model)
