# %% [markdown]
# **包含内容**
# - 环境与依赖导入
# - 设备检查
# - Decoder Mask 可视化
# - 位置编码可视化

# %%
# 导入公用工具（其余Notebook同样使用该模块）
import torch
from transformer_utils import (
    device,
    visualize_mask,
    visualize_positional_encoding,
)
print(f'当前设备: {device}')
if torch.cuda.is_available():
    print(f'GPU名称: {torch.cuda.get_device_name(0)}')

# %%
# 可视化Decoder使用的下三角mask
visualize_mask(20)

# %%
# 可视化位置编码（正弦/余弦波与热力图）
visualize_positional_encoding(d_model=20, max_len=100)
